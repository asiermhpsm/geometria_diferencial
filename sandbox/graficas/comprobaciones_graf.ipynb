# %% [markdown]
# # Comprobaciones de la representacion de superficies

# %%
from graf import *
from geoDiff import normal, normal_pt_uv, normal_pt_xyz, planoTangente, planoTangente_pt_uv, planoTangente_pt_xyz
from points import *

# %%
u, v = sp.symbols('u, v', real = True)
x, y, z = sp.symbols('x, y z', real = True)

# %%
cono = Superficie_Parametrizada([u*sp.cos(v), u*sp.sin(v), 2*u], u, v, 0, 5, 0, 2*np.pi, color_map=True)
plano = Superficie_Parametrizada([u+v, u-v, u*v], u, v, 0, 5, 0, 5, color_map=True)
grafica([cono, plano])
